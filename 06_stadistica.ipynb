# %% [markdown]
# Estadística

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
# %matplotlib inline

# %% [markdown]
# Simulacion de lanzamiento de un dado 100 veces

# %%
sample = np.random.choice([1,2,3,4,5,6], 100)

# %% [markdown]
# Se necesita saber la cantidad de cada resultado

# %%
from collections import Counter
c = Counter(sample)

# %%
print({k: v/100.0 for k, v in c.items()})
# Out:
# {1: 0.13, 2: 0.2, 3: 0.17, 4: 0.19, 5: 0.19, 6: 0.12}

# %% [markdown]
# Distribuciones continuas

# %% [markdown]
# [distribuciones](https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html)

# %% [markdown]
# Distribucion Normal
# ($\mu=0$ y  $\sigma^2=1$)

# %%
norm_rv = sts.norm(0, 1)
sample = norm_rv.rvs(100)

# %% [markdown]
# Comparamos la distribucion empirica con la teorica

# %%
x = np.linspace(-4,4,100)
cdf = norm_rv.cdf(x)
plt.plot(x, cdf, label='teorica')

from statsmodels.distributions.empirical_distribution import ECDF
ecdf = ECDF(sample)
plt.step(ecdf.x, ecdf.y, label='empirica -ECDF')

plt.ylabel('$f(x)$')
plt.xlabel('$x$')
plt.legend(loc='lower right')

# %%
plt.hist(sample,bins=7, normed=True)
plt.ylabel('Frecuencia')
plt.xlabel('$x$')

# %% [markdown]
# Estimacion de la densidad empirica y comparacion la la densidad de la distribucion normal teorica

# %%
df = pd.DataFrame(sample, columns=['KDE'])
ax = df.plot(kind='density')

x = np.linspace(-4,4,100)
pdf = norm_rv.pdf(x)
plt.plot(x, pdf, label='teorica pdf', alpha=0.5)
plt.legend()
plt.ylabel('$f(x)$')
plt.xlabel('$x$')

# %% [markdown]
# Distribuciones

# %%
norm_rv = sts.norm(2,0.5)
# genreacion de 15 valores
norm_rv.rvs(size=15)
# Out:
# array([ 1.71871386,  1.64043868,  1.94552118,  1.74087466,  2.36540037,
#         2.01103702,  2.26063269,  1.96053314,  1.06520713,  1.56907588,
#         3.0032857 ,  2.17021898,  1.52886145,  1.58021668,  1.64491094])

# %% [markdown]
# Devuelve el valor segun la funcion normal

# %%
norm_rv.cdf(3)
# Out:
# 0.97724986805182079

# %%
x = np.linspace(0,4,100)
cdf = norm_rv.cdf(x)
plt.plot(x, cdf)
plt.ylabel('$F(x)$')
plt.xlabel('$x$')

# %% [markdown]
# Calculo de probabilidad segun un punto dado

# %%
norm_rv.pdf(3)
# Out:
# 0.10798193302637613

# %% [markdown]
# Función de densidad de probabilidad

# %%
x = np.linspace(0,4,100)
pdf = norm_rv.pdf(x)
plt.plot(x, pdf)

plt.ylabel('$f(x)$')
plt.xlabel('$x$')

# %% [markdown]
# Distribucion discreta

# %% [markdown]
# Binomial

# %%
binom_rv=sts.binom(5,0.4)
